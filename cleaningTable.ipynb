# %%
import pandas as pd

# %%
df = pd.read_csv('data_jup.csv')

# %%
df
# Out:
#                                                   URL File Type  \
# 0   https://advantechgsenterprisesinc.sharepoint.c...      Word
# 1   https://advantechgsenterprisesinc.sharepoint.c...      Word
# 2   https://advantechgsenterprisesinc.sharepoint.c...     OTHER
# 3   https://advantechgsenterprisesinc.sharepoint.c...     OTHER
# 4   https://advantechgsenterprisesinc.sharepoint.c...     OTHER
# ..                                                ...       ...
# 94  https://advantechgsenterprisesinc.sharepoint.c...      Word
# 95  https://advantechgsenterprisesinc.sharepoint.c...     OTHER
# 96  https://advantechgsenterprisesinc.sharepoint.c...     OTHER
# 97  https://advantechgsenterprisesinc.sharepoint.c...     OTHER
# 98  https://advantechgsenterprisesinc.sharepoint.c...     OTHER
#
#                                             File Name        URL - Names  \
# 0   #48 Subject Matter Expert  SME  1   Edward Dea...     Edward Dearing
# 1   1 28 13   SPRDE   no acquisition   Jennifer Go...  Jennifer Gordon 1
# 2   id= HR TR RESUMES  INTERVIEWS Cleared Jobs Res...              EunOh
# 3   id= HR TR RESUMES  INTERVIEWS Cleared Jobs Res...                NaN
# 4   id= HR TR RESUMES  INTERVIEWS IT Support NW ad...                NaN
# ..                                                ...                ...
# 94                                  Valdez Julio docx       Valdez Julio
# 95  id= HR TR RESUMES  INTERVIEWS Cleared Jobs Res...                NaN
# 96  id= HR TR RESUMES  INTERVIEWS Cleared Jobs Res...                NaN
# 97  id= HR TR RESUMES  INTERVIEWS Cleared Jobs Res...                NaN
# 98  id= HR TR RESUMES  INTERVIEWS Cleared Jobs Res...                NaN
#
#                                       Content - Names         Content - Email  \
# 0   Edward Dearing \n\nResume, Diego Garcia, OT, W...   edearing@cmasvets.com
# 1   Jennifer Gordon \n\nTechnical Project, CISSP T...  jenngordon79@yahoo.com
# 2   Jennifer Gordon \n\nTechnical Project, CISSP T...  jenngordon79@yahoo.com
# 3   Jennifer Gordon \n\nTechnical Project, CISSP T...  jenngordon79@yahoo.com
# 4   Jennifer Gordon \n\nTechnical Project, CISSP T...  jenngordon79@yahoo.com
# ..                                                ...                     ...
# 94                                     syslog, Python    juliovaldez@live.com
# 95                                     syslog, Python    juliovaldez@live.com
# 96                                     syslog, Python    juliovaldez@live.com
# 97                                     syslog, Python    juliovaldez@live.com
# 98                                                NaN                     NaN
#
#                  Content - Phone
# 0                 (757) 718-7763
# 1   (858) 357-6508, 858-357-6508
# 2   (858) 357-6508, 858-357-6508
# 3   (858) 357-6508, 858-357-6508
# 4   (858) 357-6508, 858-357-6508
# ..                           ...
# 94                  757-472-6050
# 95                  757-472-6050
# 96                  757-472-6050
# 97                  757-472-6050
# 98                           NaN
#
# [99 rows x 7 columns]

# %%
df["URL - Names"].isna().sum()
# Out:
# 31

# %%
df.columns = ['url','ftype','fname','name','description','email','phone']

# %%
df.head()
# Out:
#                                                  url  ftype  \
# 0  https://advantechgsenterprisesinc.sharepoint.c...   Word
# 1  https://advantechgsenterprisesinc.sharepoint.c...   Word
# 2  https://advantechgsenterprisesinc.sharepoint.c...  OTHER
# 3  https://advantechgsenterprisesinc.sharepoint.c...  OTHER
# 4  https://advantechgsenterprisesinc.sharepoint.c...  OTHER
#
#                                                fname               name  \
# 0  #48 Subject Matter Expert  SME  1   Edward Dea...     Edward Dearing
# 1  1 28 13   SPRDE   no acquisition   Jennifer Go...  Jennifer Gordon 1
# 2  id= HR TR RESUMES  INTERVIEWS Cleared Jobs Res...              EunOh
# 3  id= HR TR RESUMES  INTERVIEWS Cleared Jobs Res...                NaN
# 4  id= HR TR RESUMES  INTERVIEWS IT Support NW ad...                NaN
#
#                                          description                   email  \
# 0  Edward Dearing \n\nResume, Diego Garcia, OT, W...   edearing@cmasvets.com
# 1  Jennifer Gordon \n\nTechnical Project, CISSP T...  jenngordon79@yahoo.com
# 2  Jennifer Gordon \n\nTechnical Project, CISSP T...  jenngordon79@yahoo.com
# 3  Jennifer Gordon \n\nTechnical Project, CISSP T...  jenngordon79@yahoo.com
# 4  Jennifer Gordon \n\nTechnical Project, CISSP T...  jenngordon79@yahoo.com
#
#                           phone
# 0                (757) 718-7763
# 1  (858) 357-6508, 858-357-6508
# 2  (858) 357-6508, 858-357-6508
# 3  (858) 357-6508, 858-357-6508
# 4  (858) 357-6508, 858-357-6508

# %%
df_sub = df[['name','email','phone']]

# %%
path = '/SCRAP_FALL_INTERN_2022'
df_sub.to_csv(index = False, path_or_buf=path)
# Out:
#   Cell In [16], line 1
#     path = 'C:\Users\Samuel Liu\General\Software\Scrap_FALL_INTERN_2022'
#                                                                         ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
